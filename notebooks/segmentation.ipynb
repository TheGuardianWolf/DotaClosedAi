# %%
import cv2 as cv
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams["figure.figsize"] = (25, 12)

# %%
img = cv.imread("Process.png")

hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

# %%
thresh1 = cv.inRange(hsv, np.array([0, 0, 0]), np.array([255, 208, 17]))

# %%
hsv[500-4,1162-3]
# Out:
# array([  4, 198,  18], dtype=uint8)

# %%
plt.imshow(thresh1[490:500,1082:1162], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(thresh1[575:585,1019:1099], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(thresh1[783:793,733:813], cmap='gray', vmin=0, vmax=255)

# %%
thresh2 = cv.inRange(hsv, np.array([27, 255, 84]), np.array([33, 255, 129]))

# %%
plt.imshow(thresh2[575:585,1019:1099], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(thresh2[783:793,733:813], cmap='gray', vmin=0, vmax=255)

# %%
thresh3 = cv.inRange(hsv, np.array([27, 255, 17]), np.array([34, 255, 29]))

# %%
plt.imshow(thresh3[575:585,1019:1099], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(thresh3[490:500,1082:1162], cmap='gray', vmin=0, vmax=255)

# %%
thresh4 = cv.inRange(hsv, np.array([5, 148, 90]), np.array([9, 159, 140]))

# %%
plt.imshow(thresh4[381:391,1391:1471], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(thresh4[490:500,1082:1162], cmap='gray', vmin=0, vmax=255)

# %%
thresh5 = cv.inRange(hsv, np.array([3, 193, 18]), np.array([9, 211, 30]))

# %%
plt.imshow(thresh5[490:500,1082:1162], cmap='gray', vmin=0, vmax=255)

# %%
hsv[490+6,(1082+28):(1082+53)]
# Out:
# array([[  4, 204,  20],
#        [  4, 204,  20],
#        [  4, 204,  20],
#        [  6, 204,  20],
#        [  6, 204,  20],
#        [  6, 204,  20],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  5, 206,  21],
#        [  6, 204,  20],
#        [  6, 204,  20],
#        [  6, 204,  20],
#        [  4, 204,  20],
#        [  4, 204,  20],
#        [  4, 204,  20],
#        [  4, 201,  19]], dtype=uint8)
